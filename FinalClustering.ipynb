# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clusterData = pd.read_csv('./Data/clusteredData.csv')
clusterData.head()
# Out:
#                   PLAYER TEAM  CLUSTER       PC1       PC2       PC3  \
# 0          Stephen Curry  GSW        8 -1.101113  2.220351 -1.601644
# 1           Bradley Beal  WAS        8 -0.364095  2.081327 -0.841141
# 2         Damian Lillard  POR        8 -1.314591  2.468844 -0.221814
# 3            Joel Embiid  PHI        2  2.593196  3.090430 -1.206564
# 4  Giannis Antetokounmpo  MIL        2  1.489888  2.944500  0.749289
#
#         PC4       PC5
# 0 -1.121010 -0.614256
# 1 -1.870946 -0.270892
# 2 -1.997488  0.587894
# 3  1.641014  4.542649
# 4 -0.422912  0.932376

# %%
clusterData[clusterData['CLUSTER']==1].head(10)
# Out:
#               PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 78   Kelly Oubre Jr.  GSW        1  0.443846  0.126226 -1.243812 -0.958782
# 82      Clint Capela  ATL        1  2.848480  0.543605  1.028642  0.025636
# 93     Thomas Bryant  WAS        1  1.304997  0.031299 -0.740391  0.251038
# 94       Rudy Gobert  UTA        1  3.112428  0.874910  0.584673  0.043323
# 128     Myles Turner  IND        1  1.514665  0.248988 -1.534398 -0.328784
# 150    Jae'Sean Tate  HOU        1  0.549750  0.208686  0.105174 -0.108863
# 163   Oshae Brissett  IND        1  0.511642 -0.354546 -1.587697 -0.582438
# 171    Mason Plumlee  DET        1  1.770788  0.608235  2.004447  0.877840
# 172   Brandon Clarke  MEM        1  0.965155 -0.228183  0.038272 -0.144913
# 186     Daniel Theis  CHI        1  1.110089 -0.203188 -0.566822  0.365550
#
#           PC5
# 78  -1.051261
# 82  -1.574327
# 93  -1.567588
# 94  -2.121625
# 128 -1.694684
# 150 -1.557184
# 163 -1.258036
# 171 -0.950255
# ...

# %%
clusterData[clusterData['CLUSTER']==2].head(10)
# Out:
#                    PLAYER TEAM  CLUSTER       PC1       PC2       PC3  \
# 3             Joel Embiid  PHI        2  2.593196  3.090430 -1.206564
# 4   Giannis Antetokounmpo  MIL        2  1.489888  2.944500  0.749289
# 7         Zion Williamson  NOP        2  1.700853  1.967938 -0.033380
# 8            Kevin Durant  BKN        2  0.093477  2.308875 -1.094220
# 12           Nikola Jokic  DEN        2  2.532788  3.533143  0.364886
# 16           LeBron James  LAL        2 -0.105178  2.405549  0.215873
# 17          Kawhi Leonard  LAC        2  0.061431  2.604205 -0.233129
# 18     Karl-Anthony Towns  MIN        2  1.925150  2.245812 -1.034014
# 22          Julius Randle  NYK        2  0.395666  2.572922 -0.271978
# 25         Nikola Vucevic  CHI        2  1.541266  2.109502 -1.342738
#
#          PC4       PC5
# 3   1.641014  4.542649
# 4  -0.422912  0.932376
# 7  -1.180875  0.007664
# 8   0.141587  1.698255
# 12  3.582430  2.157317
# 16  0.362476  1.112576
# 17  0.651019  1.641788
# ...

# %%
clusterData[clusterData['CLUSTER']==3].head(10)
# Out:
#                 PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 28        Jerami Grant  DET        3 -0.061212  1.140218 -1.155575 -0.853350
# 36      Christian Wood  HOU        3  1.621219  1.067829 -1.268131 -0.173469
# 46       Malik Beasley  MIN        3 -0.403998  0.410321 -2.200733 -0.776488
# 48     Anthony Edwards  MIN        3 -0.423940  0.934415 -0.630276 -1.759187
# 51  Michael Porter Jr.  DEN        3  0.723506  0.471432 -2.329382  0.137529
# 54       Norman Powell  POR        3 -0.610960  0.553821 -1.471090 -0.783049
# 56     Jordan Clarkson  UTA        3 -0.736730  0.951964 -0.863992 -1.075070
# 59        John Collins  ATL        3  1.575714  0.781196 -1.546135  0.242174
# 64       Evan Fournier  BOS        3 -0.590786  0.682631 -1.387941 -1.091051
# 66    Bojan Bogdanovic  UTA        3 -0.358947  0.667567 -1.916441 -0.213028
#
#          PC5
# 28  0.375707
# 36  0.179561
# 46 -0.715734
# 48 -0.338498
# 51 -0.410822
# 54 -0.868621
# 56  0.106526
# ...

# %%
clusterData[clusterData['CLUSTER']==4].head(10)
# Out:
#                PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 77      Terrence Ross  ORL        4 -0.563162  0.356225 -0.941072 -0.743290
# 125        Alec Burks  NYK        4 -0.599986  0.325855 -0.518011 -0.188739
# 141        Malik Monk  CHA        4 -0.777789 -0.235027 -0.621183 -0.491427
# 156  Lonnie Walker IV  SAS        4 -0.888287 -0.346210 -0.543870 -0.006139
# 182     Frank Jackson  DET        4 -0.367009 -0.650437 -1.106293 -0.540314
# 185   Otto Porter Jr.  ORL        4 -0.095248 -0.358433 -0.691474 -0.169238
# 190     Eric Paschall  GSW        4  0.457367 -0.264778 -0.240317 -0.987376
# 191    Taurean Prince  CLE        4 -0.220623 -0.332725 -0.775087 -1.003904
# 206     Jaylen Nowell  MIN        4 -0.526380 -0.529260 -0.411641 -1.295344
# 228      Luke Kennard  LAC        4 -0.711716 -0.532020 -0.806021  0.274181
#
#           PC5
# 77   0.797768
# 125  0.939754
# 141  1.025416
# 156  0.553766
# 182  0.645787
# 185  0.567066
# 190  1.396023
# ...

# %%
clusterData[clusterData['CLUSTER']==5].head(10)
# Out:
#                  PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 42   Kristaps Porzingis  DAL        5  1.518044  1.051939 -1.673199  1.197937
# 97           Al Horford  BOS        5  0.631881  0.489578 -0.267122  1.961973
# 106   LaMarcus Aldridge  BKN        5  0.878748  0.381657 -1.302880  1.113923
# 111   Marcus Morris Sr.  LAC        5  0.113853  0.175611 -1.772995  0.859178
# 112     Carmelo Anthony  POR        5 -0.000053  0.335439 -1.106475  0.089394
# 114    Danilo Gallinari  ATL        5  0.391064  0.304392 -1.954798 -0.485532
# 121          Kyle Kuzma  LAL        5  0.015284 -0.045404 -0.896373  0.400949
# 129          Seth Curry  PHI        5 -1.174187  0.191207 -0.929816  1.087984
# 135          Kevin Love  CLE        5  0.379423  0.188328 -0.671707  1.608379
# 143       Davis Bertans  WAS        5 -0.589746 -0.754322 -2.185433  1.105620
#
#           PC5
# 42   1.839303
# 97   1.018022
# 106  2.453727
# 111  1.408389
# 112  3.144286
# 114  2.061200
# ...

# %%
clusterData[clusterData['CLUSTER']==6].head(10)
# Out:
#             PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 19    Jaylen Brown  BOS        6 -0.223526  1.420051 -1.256557 -0.447317
# 33   Pascal Siakam  TOR        6  0.461678  1.938070  0.045321 -0.090816
# 38    Terry Rozier  CHA        6 -0.999864  1.028306 -0.948745  0.008012
# 43  Victor Oladipo  MIA        6 -0.891063  1.128280  0.101092 -0.638718
# 44  Gordon Hayward  CHA        6 -0.200867  1.297186 -1.068071 -0.774036
# 45   Fred VanVleet  TOR        6 -1.384999  1.550364  0.388326  0.633553
# 47   Tobias Harris  PHI        6  0.105334  1.442808 -0.449114  0.350462
# 49    Kemba Walker  OKC        6 -1.390405  1.130014  0.528627  0.097036
# 55  Andrew Wiggins  GSW        6 -0.008312  0.876591 -0.981223 -0.416339
# 57     Eric Gordon  HOU        6 -1.083124  0.397040 -0.378683 -0.348586
#
#          PC5
# 19 -0.421285
# 33  0.175785
# 38 -1.029734
# 43 -0.923279
# 44 -0.924046
# 45 -2.060806
# 47  0.502402
# 49 -0.042679
# 55 -0.708837
# 57  0.214635

# %%
clusterData[clusterData['CLUSTER']==7].head(10)
# Out:
#                 PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 69         Buddy Hield  SAC        7 -0.949887  0.502557 -1.442766  0.771481
# 71   Bogdan Bogdanovic  ATL        7 -0.863814  0.617538 -1.195767  0.939419
# 74          OG Anunoby  TOR        7  0.125600  0.461118 -0.995355  0.944673
# 80       Derrick White  SAS        7 -0.763448  0.553659 -0.450985  0.324957
# 87     Devonte' Graham  CHA        7 -1.499069  0.584360 -0.268029  1.209632
# 89          Lonzo Ball  NOP        7 -0.847935  0.599760 -0.480544  0.924232
# 99          Joe Harris  BKN        7 -0.401791  0.016116 -2.485581  0.699998
# 107       Kelly Olynyk  HOU        7  0.608929  0.451701 -0.753376  0.809232
# 109      Mikal Bridges  PHX        7 -0.010200  0.136554 -1.634687  0.420087
# 115    Duncan Robinson  MIA        7 -0.832426 -0.153549 -2.412094  1.342997
#
#           PC5
# 69  -1.056246
# 71  -1.131448
# 74  -1.218558
# 80  -1.444471
# 87  -0.763644
# 89  -1.471488
# ...

# %%
clusterData[clusterData['CLUSTER']==8].head(10)
# Out:
#               PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 0      Stephen Curry  GSW        8 -1.101113  2.220351 -1.601644 -1.121010
# 1       Bradley Beal  WAS        8 -0.364095  2.081327 -0.841141 -1.870946
# 2     Damian Lillard  POR        8 -1.314591  2.468844 -0.221814 -1.997488
# 5        Luka Doncic  DAL        8 -0.752333  2.994858  1.140840 -1.785263
# 6        Zach LaVine  CHI        8 -0.600232  1.945521 -1.023879 -1.827916
# 9       Kyrie Irving  BKN        8 -0.701572  2.066316 -0.308352 -1.000652
# 10      Jayson Tatum  BOS        8 -0.230150  2.154844 -0.647155 -0.867042
# 11  Donovan Mitchell  UTA        8 -1.278546  1.916745  0.241534 -0.560008
# 13      Devin Booker  PHX        8 -0.441895  2.095161 -0.386462 -0.858519
# 14        Trae Young  ATL        8 -1.767692  2.453928  1.615882 -1.755191
#
#          PC5
# 0  -0.614256
# 1  -0.270892
# 2   0.587894
# 5   1.094940
# 6  -0.967367
# 9  -0.459682
# 10  0.872445
# 11  0.003979
# ...

# %%
clusterData[clusterData['CLUSTER']==9].head(10)
# Out:
#                       PLAYER TEAM  CLUSTER       PC1       PC2       PC3  \
# 117        Tyrese Haliburton  SAC        9 -1.395789  0.562412  0.730497
# 165                Ty Jerome  OKC        9 -0.994148  0.061379  0.307602
# 166           Reggie Jackson  LAC        9 -0.843675  0.019454  0.163568
# 173             Delon Wright  SAC        9 -0.931444  0.491574  1.197764
# 175            Elfrid Payton  NYK        9 -0.527460  0.023229  1.391079
# 176             Theo Maledon  OKC        9 -1.241708  0.030973  1.298736
# 207      Talen Horton-Tucker  LAL        9 -0.613605  0.048405  1.021369
# 210  Michael Carter-Williams  ORL        9 -0.438456  0.046416  1.555272
# 217              George Hill  PHI        9 -0.774906 -0.293531  0.660791
# 218           T.J. McConnell  IND        9 -1.165866  0.624193  2.523425
#
#           PC4       PC5
# 117  0.641584 -0.552120
# 165  0.233475  1.100286
# 166  0.962135  0.245562
# 173  0.068438 -1.270226
# 175 -0.516842  0.069555
# ...

# %%
clusterData[clusterData['TEAM']=='PHI'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 277     Dwight Howard  PHI        1  1.863793 -0.339482  1.192179 -0.571219
# 3         Joel Embiid  PHI        2  2.593196  3.090430 -1.206564  1.641014
# 236      Tyrese Maxey  PHI        4 -0.932931 -0.462728  0.857066 -0.646284
# 379        Mike Scott  PHI        4 -0.163530 -1.348909 -0.551528  0.851211
# 129        Seth Curry  PHI        5 -1.174187  0.191207 -0.929816  1.087984
# 202    Furkan Korkmaz  PHI        5 -0.764026 -0.617811 -0.983584  0.212834
# 47      Tobias Harris  PHI        6  0.105334  1.442808 -0.449114  0.350462
# 118      Shake Milton  PHI        6 -0.869866  0.373716  0.282885 -0.774212
# 192       Danny Green  PHI        7 -0.506318 -0.402195 -1.178446  1.699159
# 387  Matisse Thybulle  PHI        7 -0.462949 -1.236565  0.224127  1.063300
# 95        Ben Simmons  PHI        8  0.230112  1.471301  1.701348  0.750179
# ...

# %%
clusterData[clusterData['TEAM']=='BKN'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                       PLAYER TEAM  CLUSTER       PC1       PC2       PC3  \
# 211              Bruce Brown  BKN        1  0.659268 -0.380891  0.471499
# 258           DeAndre Jordan  BKN        1  1.970768 -0.364112  1.513088
# 294              Nic Claxton  BKN        1  1.518693 -0.682485  0.640610
# 8               Kevin Durant  BKN        2  0.093477  2.308875 -1.094220
# 159               Jeff Green  BKN        3  0.252681 -0.072653 -1.442230
# 106        LaMarcus Aldridge  BKN        5  0.878748  0.381657 -1.302880
# 160            Blake Griffin  BKN        5  0.410039  0.416591 -0.085929
# 197            Landry Shamet  BKN        5 -0.831304 -0.619887 -1.261335
# 304  Timothe Luwawu-Cabarrot  BKN        5 -0.251480 -1.020340 -0.843142
# 332            Tyler Johnson  BKN        5 -1.001049 -1.026055  0.104225
# 99                Joe Harris  BKN        7 -0.401791  0.016116 -2.485581
# 9               Kyrie Irving  BKN        8 -0.701572  2.066316 -0.308352
# ...

# %%
clusterData[clusterData['TEAM']=='MIL'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                     PLAYER TEAM  CLUSTER       PC1       PC2       PC3  \
# 4    Giannis Antetokounmpo  MIL        2  1.489888  2.944500  0.749289
# 132            Brook Lopez  MIL        3  1.229104  0.033984 -1.785482
# 146           Bobby Portis  MIL        3  0.976173 -0.045276 -0.882593
# 265         Justin Jackson  MIL        4 -0.525570 -0.716979 -0.635326
# 179            Bryn Forbes  MIL        5 -0.861169 -0.844316 -1.023515
# 284        Pat Connaughton  MIL        5 -0.201273 -0.905857 -0.902997
# 58            Jrue Holiday  MIL        6 -0.638314  1.385797  0.740983
# 169       Donte DiVincenzo  MIL        7 -0.522278 -0.010065 -0.064372
# 389            P.J. Tucker  MIL        7 -0.208698 -1.006951  0.157469
# 39         Khris Middleton  MIL        8 -0.488623  1.590044 -0.474016
# 287            Jeff Teague  MIL        9 -1.042899 -0.147705  1.448995
#
#           PC4       PC5
# 4   -0.422912  0.932376
# 132 -0.338635  0.096804
# 146  0.173330  0.396774
# ...

# %%
clusterData[clusterData['TEAM']=='NYK'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                 PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 227  Mitchell Robinson  NYK        1  1.712667 -0.658250  1.704165  0.239832
# 337         Taj Gibson  NYK        1  1.270317 -0.554175  0.799989  0.607932
# 350       Nerlens Noel  NYK        1  1.390565 -0.554551  1.473778 -0.095732
# 22       Julius Randle  NYK        2  0.395666  2.572922 -0.271978  1.256284
# 125         Alec Burks  NYK        4 -0.599986  0.325855 -0.518011 -0.188739
# 162     Reggie Bullock  NYK        5 -0.852625 -0.378039 -1.885395  1.476862
# 60          RJ Barrett  NYK        6 -0.248240  0.865629 -0.839994 -0.635467
# 147  Immanuel Quickley  NYK        6 -1.175924 -0.012475  0.125068 -0.445581
# 88        Derrick Rose  NYK        8 -1.041948  0.894372  0.883433 -0.315051
# 175      Elfrid Payton  NYK        9 -0.527460  0.023229  1.391079 -0.516842
#
#           PC5
# 227 -2.713984
# 337 -1.017498
# 350 -2.421660
# 22   0.617123
# 125  0.939754
# 162 -0.505127
# ...

# %%
clusterData[clusterData['TEAM']=='ATL'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                 PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 82        Clint Capela  ATL        1  2.848480  0.543605  1.028642  0.025636
# 369     Onyeka Okongwu  ATL        1  1.632823 -1.070506  0.917454 -2.067658
# 59        John Collins  ATL        3  1.575714  0.781196 -1.546135  0.242174
# 85     De'Andre Hunter  ATL        3  0.241478  0.628231 -1.507047 -1.131044
# 151        Cam Reddish  ATL        3 -0.132812 -0.193136 -0.962317 -1.709788
# 360    Brandon Goodwin  ATL        4 -1.141974 -0.765370  1.178626 -0.523317
# 114   Danilo Gallinari  ATL        5  0.391064  0.304392 -1.954798 -0.485532
# 338         Tony Snell  ATL        5 -0.893132 -1.011440 -0.701850  1.953482
# 371       Solomon Hill  ATL        5 -0.387742 -1.028794  0.019436  1.338395
# 71   Bogdan Bogdanovic  ATL        7 -0.863814  0.617538 -1.195767  0.939419
# 140      Kevin Huerter  ATL        7 -0.757902  0.219428 -0.566631  0.459337
# ...

# %%
clusterData[clusterData['TEAM']=='MIA'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 270    Dewayne Dedmon  MIA        1  1.639121 -0.560383  0.549964 -0.235356
# 355  Precious Achiuwa  MIA        1  1.236812 -1.185840  1.279488 -1.681598
# 53        Bam Adebayo  MIA        2  1.948419  1.983577  0.437476  1.620122
# 300   Nemanja Bjelica  MIA        4  0.090823 -0.652174  0.179080 -0.054370
# 312         Max Strus  MIA        4 -0.492683 -1.333752 -1.010419  0.206887
# 361      Gabe Vincent  MIA        4 -0.756194 -1.054013 -0.007789 -0.848946
# 193      Trevor Ariza  MIA        5  0.026005 -0.330007 -0.898331  0.784887
# 43     Victor Oladipo  MIA        6 -0.891063  1.128280  0.101092 -0.638718
# 83        Tyler Herro  MIA        6 -0.744567  0.577453 -0.373913 -0.635780
# 90      Kendrick Nunn  MIA        6 -0.750154  0.275467 -1.005175 -0.092859
# 110      Goran Dragic  MIA        6 -0.836835  0.627275  0.357468  0.353437
# ...

# %%
clusterData[clusterData['TEAM']=='UTA'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 94        Rudy Gobert  UTA        1  3.112428  0.874910  0.584673  0.043323
# 330    Derrick Favors  UTA        1  1.632206 -0.827346  1.112980 -0.695099
# 56    Jordan Clarkson  UTA        3 -0.736730  0.951964 -0.863992 -1.075070
# 66   Bojan Bogdanovic  UTA        3 -0.358947  0.667567 -1.916441 -0.213028
# 278     Georges Niang  UTA        5 -0.363494 -1.050540 -1.401514  1.104052
# 72        Mike Conley  UTA        6 -1.416050  1.394497  0.377784  0.456476
# 138        Joe Ingles  UTA        7 -1.383730  0.588678  0.199595  2.183748
# 276     Royce O'Neale  UTA        7 -0.368009 -0.193414 -0.194965  2.639161
# 11   Donovan Mitchell  UTA        8 -1.278546  1.916745  0.241534 -0.560008
#
#           PC5
# 94  -2.121625
# 330 -1.117147
# 56   0.106526
# 66   0.013839
# 278  0.127946
# 72  -1.072707
# 138 -0.795755
# 276 -2.332883
# 11   0.003979

# %%
clusterData[clusterData['TEAM']=='PHX'].sort_values(by=['CLUSTER']).head(20)
# Out:
#               PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 91     Deandre Ayton  PHX        2  2.522011  0.900283  0.113484  1.107033
# 292      Abdel Nader  PHX        4  0.016928 -0.985308 -0.611820 -0.405276
# 297   Frank Kaminsky  PHX        4  0.639240 -0.588304  0.178635  0.578365
# 329     Torrey Craig  PHX        4  0.119290 -1.045859  0.168280  0.482336
# 357    E'Twaun Moore  PHX        4 -0.406790 -0.740977  0.749963 -0.923472
# 189  Cameron Johnson  PHX        5 -0.465907 -0.639064 -1.193948  1.116512
# 213      Dario Saric  PHX        5  0.846622 -0.196950 -0.393898  0.691928
# 109    Mikal Bridges  PHX        7 -0.010200  0.136554 -1.634687  0.420087
# 178      Jae Crowder  PHX        7 -0.296686 -0.284977 -1.029148  2.141655
# 13      Devin Booker  PHX        8 -0.441895  2.095161 -0.386462 -0.858519
# 70        Chris Paul  PHX        8 -1.481551  2.016660  1.611948  0.389364
# ...

# %%
clusterData[clusterData['TEAM']=='DEN'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                  PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 262        JaVale McGee  DEN        1  1.503832 -0.447007  0.772164 -0.121244
# 12         Nikola Jokic  DEN        2  2.532788  3.533143  0.364886  3.582430
# 51   Michael Porter Jr.  DEN        3  0.723506  0.471432 -2.329382  0.137529
# 208        Paul Millsap  DEN        5  0.528726 -0.207284 -0.064191  0.634076
# 233      JaMychal Green  DEN        5  0.557637 -0.719027 -0.519146  0.998234
# 246         P.J. Dozier  DEN        5 -0.263374 -0.439063  0.185839  0.322700
# 126         Will Barton  DEN        6 -0.357479  0.394666 -0.355308 -0.019720
# 131        Aaron Gordon  DEN        6  0.458668  0.610747  0.255407  0.365253
# 174        Monte Morris  DEN        6 -1.069131  0.116299  0.391163  0.431518
# 311    Facundo Campazzo  DEN        7 -1.333818 -0.397701  0.971444  1.358703
# 34         Jamal Murray  DEN        8 -0.814350  1.604490 -0.376008 -0.544221
# ...

# %%
clusterData[clusterData['TEAM']=='LAC'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                 PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 17       Kawhi Leonard  LAC        2  0.061431  2.604205 -0.233129  0.651019
# 205        Ivica Zubac  LAC        2  2.215885  0.143391  0.445414  0.190766
# 228       Luke Kennard  LAC        4 -0.711716 -0.532020 -0.806021  0.274181
# 273       Terance Mann  LAC        4 -0.184444 -0.514316  0.333259 -0.096518
# 345  Patrick Patterson  LAC        4  0.065175 -1.125547 -1.105329 -0.153267
# 111  Marcus Morris Sr.  LAC        5  0.113853  0.175611 -1.772995  0.859178
# 157        Serge Ibaka  LAC        5  1.302442  0.077370 -0.328403  1.241490
# 209   DeMarcus Cousins  LAC        5  0.625831 -0.043106  0.001294  1.051217
# 234      Nicolas Batum  LAC        7 -0.165348 -0.417324 -0.537540  2.402942
# 255   Patrick Beverley  LAC        7 -0.839234 -0.476222  0.431224  1.799358
# 26         Paul George  LAC        8 -0.606585  1.896572 -0.468173  0.247543
# ...

# %%
clusterData[clusterData['TEAM']=='DAL'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                   PLAYER TEAM  CLUSTER       PC1       PC2       PC3  \
# 314        Dwight Powell  DAL        1  1.137012 -0.477087  0.177173
# 340  Willie Cauley-Stein  DAL        1  1.060850 -0.931330  0.792557
# 67      Tim Hardaway Jr.  DAL        3 -0.356550  0.254722 -2.277136
# 42    Kristaps Porzingis  DAL        5  1.518044  1.051939 -1.673199
# 259            JJ Redick  DAL        5 -1.260958 -1.103324 -0.145773
# 271          Maxi Kleber  DAL        5 -0.017572 -0.669037 -1.107592
# 127        Jalen Brunson  DAL        6 -0.921352  0.437731  0.429520
# 136      Josh Richardson  DAL        6 -0.713418  0.229897 -0.061391
# 181  Dorian Finney-Smith  DAL        7 -0.095724 -0.321690 -0.812615
# 5            Luka Doncic  DAL        8 -0.752333  2.994858  1.140840
# 293           Trey Burke  DAL        9 -1.160779 -0.803627  0.499747
# 392         Nicolo Melli  DAL        9 -0.325719 -1.312546  0.850435
#
#           PC4       PC5
# 314 -0.822592  0.492399
# ...

# %%
clusterData[clusterData['TEAM']=='POR'].sort_values(by=['CLUSTER']).head(20)
# Out:
#                 PLAYER TEAM  CLUSTER       PC1       PC2       PC3       PC4  \
# 282  Derrick Jones Jr.  POR        1  0.286231 -1.026743 -0.337604 -0.366524
# 145       Jusuf Nurkic  POR        2  1.881564  0.742281  0.568198  1.021529
# 154       Enes Freedom  POR        2  2.231689  0.226087  0.476299 -0.614770
# 54       Norman Powell  POR        3 -0.610960  0.553821 -1.471090 -0.783049
# 368      Nassir Little  POR        4  0.009154 -1.175782 -0.260230 -0.855469
# 112    Carmelo Anthony  POR        5 -0.000053  0.335439 -1.106475  0.089394
# 222   Robert Covington  POR        7 -0.070064 -0.222746 -0.661033  2.016507
# 2       Damian Lillard  POR        8 -1.314591  2.468844 -0.221814 -1.997488
# 27         CJ McCollum  POR        8 -1.227402  1.407849 -0.593834 -0.377635
# 241    Anfernee Simons  POR        9 -0.991423 -0.656519  0.164312  0.783107
#
#           PC5
# 282 -1.130105
# 145  0.320714
# 154 -0.003582
# 54  -0.868621
# 368  1.909584
# 112  3.144286
# ...
